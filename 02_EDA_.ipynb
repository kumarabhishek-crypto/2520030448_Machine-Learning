# %% [markdown]
# <a href="https://colab.research.google.com/github/kumarabhishek-crypto/2520030448_Machine-Learning/blob/main/02_EDA_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import seaborn as sns

# %%
#https://www.kaggle.com/datasets/sonalshinde123/student-placement-dataset
from pandas import read_csv
df=read_csv('C:\\KLH\\Subjects\\ML(Y25)\\datasets\\placement_predict_50k Dataset.csv')

# %%
# Numerical vs Categorical features
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns
categorical_features = df.select_dtypes(include=['object']).columns

print("Numerical Features:", list(numerical_features))
print("Categorical Features:", list(categorical_features))
# Out:
# Numerical Features: ['StudentID', 'SGPA_Sem1', 'SGPA_Sem2', 'SGPA_Sem3', 'SGPA_Sem4', 'SGPA_Sem5', 'SGPA_Sem6', 'SGPA_Sem7', 'SGPA_Sem8', 'CGPA', 'AttendancePercent', 'Internships', 'Projects', 'Workshops', 'Certifications', 'Publications', 'AptitudeTestScore', 'SoftSkillsRating', 'CodingTestScore', 'MockInterviewScore', 'ExtraCurricular', 'PlacementStatus', 'IsAnomaly']
# Categorical Features: ['Gender', 'City', 'CollegeTier', 'Stream', 'Specialisation', 'Hostel', 'HistoryOfBacklogs', 'CGPA_Tier']
# C:\Users\nirma\AppData\Local\Temp\ipykernel_25732\1869842994.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_features = df.select_dtypes(include=['object']).columns

# %%
# Select only numerical columns for correlation
numerical_cols = df.select_dtypes(include=[np.number]).columns.tolist()
corr_matrix = df[numerical_cols].corr()

# %%
# Print matrix to terminal
print("\n--- Correlation Matrix ---")
print(corr_matrix)
# Out:
# --- Correlation Matrix ---
#                     StudentID  SGPA_Sem1  SGPA_Sem2  SGPA_Sem3  SGPA_Sem4  \
# StudentID            1.000000  -0.004221  -0.004321  -0.003670  -0.002203
# SGPA_Sem1           -0.004221   1.000000   0.963951   0.963790   0.963600
# SGPA_Sem2           -0.004321   0.963951   1.000000   0.964915   0.964800
# SGPA_Sem3           -0.003670   0.963790   0.964915   1.000000   0.965753
# SGPA_Sem4           -0.002203   0.963600   0.964800   0.965753   1.000000
# SGPA_Sem5           -0.002920   0.963188   0.964754   0.965477   0.966570
# SGPA_Sem6           -0.002474   0.962474   0.964251   0.965877   0.966524
# SGPA_Sem7           -0.002470   0.961925   0.963900   0.965480   0.966349
# SGPA_Sem8           -0.003057   0.960640   0.962899   0.964778   0.966118
# CGPA                -0.002534   0.911463   0.912570   0.913174   0.913727
# AttendancePercent    0.000299   0.496737   0.506104   0.513868   0.521876
# Internships          0.002501   0.446370   0.455718   0.462060   0.468551
# Projects             0.005667   0.505847   0.514388   0.523531   0.530917
# Workshops            0.002363   0.535894   0.545208   0.554390   0.563920
# Certifications       0.004367   0.550270   0.560730   0.568944   0.578164
# Publications         0.004312   0.456837   0.464832   0.472170   0.479912
# AptitudeTestScore    0.013300   0.495157   0.506474   0.514147   0.522157
# SoftSkillsRating     0.004275   0.526000   0.535582   0.543593   0.551821
# CodingTestScore      0.005544   0.546014   0.555802   0.563893   0.572906
# MockInterviewScore   0.004961   0.607541   0.618142   0.627260   0.637048
# ExtraCurricular      0.002366   0.213115   0.215642   0.220034   0.222013
# PlacementStatus     -0.001296   0.665039   0.672252   0.677780   0.683972
# IsAnomaly           -0.005568  -0.005927  -0.004047  -0.004581  -0.006518
#
#                     SGPA_Sem5  SGPA_Sem6  SGPA_Sem7  SGPA_Sem8      CGPA  ...  \
# StudentID           -0.002920  -0.002474  -0.002470  -0.003057 -0.002534  ...
# SGPA_Sem1            0.963188   0.962474   0.961925   0.960640  0.911463  ...
# SGPA_Sem2            0.964754   0.964251   0.963900   0.962899  0.912570  ...
# SGPA_Sem3            0.965477   0.965877   0.965480   0.964778  0.913174  ...
# SGPA_Sem4            0.966570   0.966524   0.966349   0.966118  0.913727  ...
# SGPA_Sem5            1.000000   0.967442   0.967439   0.967389  0.913726  ...
# SGPA_Sem6            0.967442   1.000000   0.968361   0.968433  0.913601  ...
# CodingTestScore              0.810048          0.663133         1.000000
# MockInterviewScore           0.688509          0.731849         0.752965
# ExtraCurricular              0.245156          0.258493         0.272555
# PlacementStatus              0.577749          0.624788         0.612832
# IsAnomaly                   -0.036637         -0.004894        -0.053900
#
#                     MockInterviewScore  ExtraCurricular  PlacementStatus  \
# StudentID                     0.004961         0.002366        -0.001296
# SGPA_Sem1                     0.607541         0.213115         0.665039
# SGPA_Sem2                     0.618142         0.215642         0.672252
# SGPA_Sem3                     0.627260         0.220034         0.677780
# SGPA_Sem4                     0.637048         0.222013         0.683972
# SGPA_Sem5                     0.646865         0.226999         0.690914
# SGPA_Sem6                     0.655004         0.230975         0.695881
# SGPA_Sem7                     0.664418         0.234979         0.701972
# SGPA_Sem8                     0.673852         0.237325         0.707147
# CGPA                          0.604231         0.213782         0.648926
# AttendancePercent             0.684834         0.247735         0.554024
# Internships                   0.619148         0.224955         0.526197
# Projects                      0.704938         0.254391         0.580122
# Workshops                     0.738732         0.265209         0.581535
# Certifications                0.764394         0.272870         0.601315
# Publications                  0.629232         0.228229         0.469351
# AptitudeTestScore             0.688509         0.245156         0.577749
# SoftSkillsRating              0.731849         0.258493         0.624788
# CodingTestScore               0.752965         0.272555         0.612832
# MockInterviewScore            1.000000         0.299292         0.668000
# ExtraCurricular               0.299292         1.000000         0.239572
# PlacementStatus               0.668000         0.239572         1.000000
# IsAnomaly                     0.000197         0.005944         0.000009
#
#                     IsAnomaly
# StudentID           -0.005568
# SGPA_Sem1           -0.005927
# SGPA_Sem2           -0.004047
# SGPA_Sem3           -0.004581
# SGPA_Sem4           -0.006518
# SGPA_Sem5           -0.003880
# SGPA_Sem6           -0.004343
# SGPA_Sem7           -0.004707
# SGPA_Sem8           -0.002036
# CGPA                -0.022649
# AttendancePercent   -0.181062
# Internships          0.216208
# Projects             0.223433
# Workshops           -0.003173
# Certifications      -0.000276
# Publications        -0.007899
# AptitudeTestScore   -0.036637
# SoftSkillsRating    -0.004894
# CodingTestScore     -0.053900
# MockInterviewScore   0.000197
# ExtraCurricular      0.005944
# PlacementStatus      0.000009
# IsAnomaly            1.000000
#
# [23 rows x 23 columns]

# %%
# Create Heatmap
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
sns.heatmap(
corr_matrix,
annot=True,
cmap="coolwarm",
fmt=".2f",
vmin=-1,
vmax=1,
square=True,
linewidths=0.5
)
plt.title("Correlation Heatmap of Numerical Features", fontsize=14, fontweight="bold")
plt.tight_layout()

# %%
# Export Heatmap
import os
output_dir = "C:\\KLH\\Subjects\\ML(Y25)\\PlacementPredict\\reports"
heatmap_path = os.path.join(output_dir, "correlation_heatmap.png")
plt.savefig(heatmap_path, dpi=300)
plt.close()
print(f"Exported heatmap to: {heatmap_path}")
# Out:
# Exported heatmap to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\correlation_heatmap.png

# %%
# -------------------------------------------------------------
# 3. Produce Boxplots: Numerical Features vs PlacementStatus
# -------------------------------------------------------------
target_col = "PlacementStatus"
if target_col in df.columns:
    for col in numerical_cols:
        plt.figure(figsize=(6, 5))
        sns.boxplot(
            x=target_col,
            y=col,
            data=df,
            palette="Set2",
            hue=target_col,
            legend=False
        )
        plt.title(f"{col} vs {target_col}", fontsize=12, fontweight="bold")
        plt.xlabel(target_col)
        plt.ylabel(col)
        plt.tight_layout()


        # Save the boxplot
        boxplot_filename = f"boxplot_{col}_vs_{target_col}.png"

        # Create complete file path
        boxplot_path = os.path.join(output_dir, boxplot_filename)

        # Save the figure
        plt.savefig(boxplot_path,    dpi=300,    bbox_inches="tight")

        # Close the figure
        plt.close()

        # Display confirmation message
        print(f"Exported boxplot to: {boxplot_path}")

    else:
        print(f"\nTarget column '{target_col}' not found in dataset. Skipping boxplots.")

        print("\nAll EDA tasks completed successfully!")
# Out:
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_StudentID_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_SGPA_Sem1_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_SGPA_Sem2_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_SGPA_Sem3_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_SGPA_Sem4_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_SGPA_Sem5_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_SGPA_Sem6_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_SGPA_Sem7_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_SGPA_Sem8_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_CGPA_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_AttendancePercent_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_Internships_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_Projects_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_Workshops_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_Certifications_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_Publications_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_AptitudeTestScore_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_SoftSkillsRating_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_CodingTestScore_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_MockInterviewScore_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_ExtraCurricular_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_PlacementStatus_vs_PlacementStatus.png
# Exported boxplot to: C:\KLH\Subjects\ML(Y25)\PlacementPredict\reports\boxplot_IsAnomaly_vs_PlacementStatus.png
#
# Target column 'PlacementStatus' not found in dataset. Skipping boxplots.
#
# All EDA tasks completed successfully!

# %%
import matplotlib.pyplot as plt
fig1=plt.figure(figsize=(12,6))

sns.heatmap(
         df.isnull(),
        cbar=False,
         cmap="viridis"
)

plt.title("Missing Value Heatmap")

plt.show()

# %% [markdown]
# ### **Observation**
#
# The missing value heatmap shows a uniform color across all features, indicating that the dataset does not contain missing values. Therefore, no data imputation is required before model training.

# %%
features = ["CGPA", "Age", "Coding_Skills", "Communication_Skills","Aptitude_Test_Score", "Backlogs" ]

fig2=plt.figure(figsize=(15,8))
df[features].hist(
    bins=20
)

plt.tight_layout()

plt.show()

# %% [markdown]
# #Observations:
# ### **1. CGPA**
#
# Observation:
#
# - The CGPA values approximately follow a bell-shaped (near normal) distribution.
# - Most students have a CGPA between 6.0 and 8.0.
# - Very few students have extremely low (<5) or very high (>9) CGPA values.
# - The feature appears suitable for machine learning without major preprocessing.
#
# ### **2. Age**
#
# Observation:
#
# - Students' ages range from 18 to 24 years.
# - The distribution is nearly uniform, indicating a balanced representation across age groups.
# -  No unusual age values or outliers are observed.
#
#
# ### **3. Coding Skills**
#
# Observation:
#
# - Coding skill ratings range from 1 to 10.
# - Most students have coding skills between 5 and 7.
# - Very few students have extremely low or extremely high coding skill scores.
# - The distribution is approximately symmetric.
#
# ### **4. Communication Skills**
#
# Observation:
#
# - Communication skill ratings also range from 1 to 10.
# - Most students scored between 5 and 7, indicating average communication abilities.
# - Extremely low and extremely high ratings are less frequent.
#
# ### **5. Backlogs**
#
# Observation:
#
# - The majority of students have zero backlogs.
# - As the number of backlogs increases, the number of students decreases significantly.
# - The distribution is positively (right) skewed, indicating that only a small proportion of students have multiple backlogs.

# %%
#Placement rate by branch

fig3=plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="Branch",
    hue="Placement_Status"
)

plt.title("Placement Status by Branch")

plt.show()

# %%
#Corelation Heatmap

fig5= plt.figure(figsize=(10,8))

corr = df.select_dtypes(include=np.number).corr()

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# # Correlation Heatmap
#
# To identify the relationship among numerical features and understand which variables are positively or negatively correlated before model development.
# A correlation heatmap visualizes the Pearson correlation coefficient between numerical features.
#
# The correlation coefficient (r) ranges from **-1 to +1**.
#
# - **+1** → Perfect positive correlation
# - **0** → No correlation
# - **-1** → Perfect negative correlation
#
# Generally,
#
# - **0.70 to 1.00** → Strong positive correlation
# - **0.40 to 0.69** → Moderate positive correlation
# - **0.00 to 0.39** → Weak positive correlation
# - **-0.40 to -0.69** → Moderate negative correlation
# - **-0.70 to -1.00** → Strong negative correlation
#
# ##Example:
#
# # **1. Coding Skills vs Certifications = 0.86**
# Observation
# -A strong positive relationship exists.
# -Students with better coding skills usually earn more certifications.
# -Certifications appear to reflect technical competency.
#
#
# # 2. Student_ID, Correlation ≈ 0
# Observation
#
# - It has no relationship with placement or academic performance.
# - It should be removed before model training.
#
# #3.CGPA vs Backlogs = -0.58
#     -As CGPA increases, the number of backlogs generally decreases.

# %%
#boxplots
numerical_columns = [
    "Age",
    "CGPA",
    "Internships",
    "Projects",
    "Coding_Skills",
    "Communication_Skills",
    "Aptitude_Test_Score",
    "Soft_Skills_Rating",
    "Certifications",
    "Backlogs"
]


fig6= plt.figure(figsize=(14,8))

df[numerical_columns].boxplot()

plt.xticks(rotation=45)

plt.show()

# %%
fig7= sns.boxplot(x='Placement_Status', y='Certifications', data=df)

# %%
from matplotlib.backends.backend_pdf import PdfPages

with PdfPages("EDA_Report.pdf") as pdf:

    pdf.savefig(fig1)
    pdf.savefig(fig2)
    pdf.savefig(fig3)
    pdf.savefig(fig5)
    pdf.savefig(fig6)


print("EDA Report saved successfully.")
# Out:
# EDA Report saved successfully.

# %%
#==========================================================
# Export Complete EDA Report
#==========================================================

with PdfPages("EDA_Report.pdf") as pdf:

    #------------------------------------------------------
    # Page 1 : Missing Value Heatmap
    #------------------------------------------------------

    plt.figure(figsize=(12,6))

    sns.heatmap(df.isnull(),
                cbar=True,
                yticklabels=False,
                cmap="viridis")

    plt.title("Missing Value Heatmap")
    plt.xlabel("Features")
    plt.ylabel("Samples")

    pdf.savefig()
    plt.close()


    #------------------------------------------------------
    # Page 2 : Histograms (6 Features)
    #------------------------------------------------------

    numerical_features = [
        "CGPA",
        "Age",
        "Coding_Skills",
        "Communication_Skills",
        "Aptitude_Test_Score",
        "Backlogs"
    ]

    fig, axes = plt.subplots(3,2,figsize=(14,12))

    axes = axes.flatten()

    for i,col in enumerate(numerical_features):

        axes[i].hist(df[col],
                     bins=15,
                     edgecolor='black')

        axes[i].set_title(col)

    plt.tight_layout()

    pdf.savefig()
    plt.close()


    #------------------------------------------------------
    # Page 3 : Placement by Branch
    #------------------------------------------------------

    plt.figure(figsize=(10,6))

    sns.countplot(
        data=df,
        x="Branch",
        hue="Placement_Status"
    )

    plt.title("Placement Status by Branch")

    plt.xticks(rotation=45)

    pdf.savefig()
    plt.close()


    #------------------------------------------------------
    # Page 4 : Correlation Heatmap
    #------------------------------------------------------

    plt.figure(figsize=(10,8))

    corr = df.select_dtypes(include=np.number).corr()

    sns.heatmap(
        corr,
        annot=True,
        cmap="coolwarm",
        fmt=".2f"
    )

    plt.title("Correlation Heatmap")

    pdf.savefig()

    plt.close()


    #------------------------------------------------------
    # Page 5 : Boxplots
    #------------------------------------------------------

    fig, axes = plt.subplots(3,2,figsize=(14,12))

    axes = axes.flatten()

    for i,col in enumerate(numerical_features):

        sns.boxplot(
            y=df[col],
            ax=axes[i]
        )

        axes[i].set_title(col)

    plt.tight_layout()

    pdf.savefig()

    plt.close()

print("EDA_Report.pdf created successfully.")
